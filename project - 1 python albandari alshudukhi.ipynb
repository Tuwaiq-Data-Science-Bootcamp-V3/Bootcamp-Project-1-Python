# %%
#Risk Tolerance Questionnaire from this website https://s21.q4cdn.com/198919461/files/doc_downloads/enterprise-components/assessment_reports/IWT_CurrentReport_RiskToleranceQuest.pdf
#Release date 07-31-2018

def RiskQues():
    Score=0
    print('enter the number of answer')                     #https://bobbyhadz.com/blog/python-input-validation
    while True:
        try:
            age=int(input("what is your current age ?\n1)less than 45 \n2)45 to 55\n3)56 to 65\n4)66 to 75\n5)Older than 75\n  "))
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if age >= 1 and age <= 5:
            break
        else:
            print('The integer must be in the range 1-5')
   
    if int(age)==1:
        Score+=5
    elif int(age)==2:
        Score+=4
    elif int(age)==3:
        Score+=3
    elif int(age)==4:
        Score+=2
    else:
        Score+=1
   

    print('enter the number of answer')
    while True:
        try:
            income=int(input('When do you expect to start drawing income?\n1)Not for at least 20 years\n2)In 10 to 20 years\n3)In 5 to 10 years\n4)Not now, but within 5 years\n5)Immediately\n'))     
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if income >= 1 and income <= 5:
            break
        else:
            print('The integer must be in the range 1-5')    
    if int(income)==1:
        Score+=5
    elif int(income)==2:
        Score+=4
    elif int(income)==3:
        Score+=3
    elif int(income)==4:
        Score+=2
    else:
        Score+=1
    
    
    
    while True:
        try:
            goal=int(input('What is your goal for this investment?\n1)To grow aggressively\n2)To grow significantly\n3)To grow moderately\n4)To grow with caution\n5)To avoid losing money\n '))
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if goal >= 1 and goal <= 5:
            break
        else:
            print('The integer must be in the range 1-5')  
    if int(goal)==1:
        Score+=5
    elif int(goal)==2:
        Score+=4
    elif int(goal)==3:
        Score+=3
    elif int(goal)==4:
        Score+=2
    else:
        Score+=1
    
    
    while True:
        try:
            expect=int(input('Assuming normal market conditions, what would you expect from this investment over time?\n1)To generally keep pace with the stock market\n2)To slightly trail the stock market, but make a good profit\n3)To trail the stock market, but make a moderate profit\n4)To have some stability, but make modest profits\n5)To have a high degree of stability, but make small profits\n'))    
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if expect >= 1 and expect <= 5:
            break
        else:
            print('The integer must be in the range 1-5')  

    if int(expect)==1:
        Score+=5
    elif int(expect)==2:
        Score+=4
    elif int(expect)==3:
        Score+=3
    elif int(expect)==4:
        Score+=2
    else:
        Score+=1
    
    while True:
        try:
            unusuall=int(input('Suppose the stock market performs unusually poorly over the next decade, what would you expect from this investment?\n1)To lose money\n2)To make very little or nothing\3)To git out a little gain\n4)To make a modest gain\n5)To be little affected by what happens in the stock market \n'))
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if unusuall >= 1 and unusuall <= 5:
            break
        else:
            print('The integer must be in the range 1-5')  

    if int(unusuall)==1:
        Score+=5
    elif int(unusuall)==2:
        Score+=4
    elif int(unusuall)==3:
        Score+=3
    elif int(unusuall)==4:
        Score+=2
    else:
        Score+=1  
    
    while True:
        try:
            describe=int(input("Which of these statements would best describe your attitudes aboutthe next three years' performance of this investment?\n1)I don't mind if I lose money\n2)I can tolerate a loss\n3)I can tolerate a small loss\n4)I'd have a hard time tolerating any losses\n5)I need to see at least a little return\n"))
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if describe >= 1 and describe <= 5:
            break
        else:
            print('The integer must be in the range 1-5')  

    if int(describe)==1:
        Score+=5
    elif int(describe)==2:
        Score+=4
    elif int(describe)==3:
        Score+=3
    elif int(describe)==4:
        Score+=2
    else:
        Score+=1 
    
    while True:
        try:
            describe_month=int(input("Which of these statements would best describe your attitudes about the next three months' performance of this investment?\n1)Who cares? One calendar quarter means nothing.\n2)I wouldn't worry about losses in that time frame\n3)If I suffered a loss of greater than 10%, I'd get concerned\n4)I can only tolerate small short-term losses\n5)I'd have a hard time accepting any losses\n"))
        except ValueError:
            print("Please enter a valid integer 1-5")
            continue
        if describe >= 1 and describe <= 5:
            break
        else:
            print('The integer must be in the range 1-5')  

    if int(describe_month)==1:
        Score+=5
    elif int(describe_month)==2:
        Score+=4
    elif int(describe_month)==3:
        Score+=3
    elif int(describe_month)==4:
        Score+=2
    else:
        Score+=1
    
    
    
    
    if (Score >=7) &(Score<=10):
        degree1='Very Conservative'
        print('you are : ',degree1)
        print('your invetgate plan is : \n1)10%Stock\n2)20%Sukuk\n3)70%Real Estate')
    elif (Score >=11) &(Score<=17):
        degree2='Conservative'
        print('you are : ',degree2)
        print('your invetgate plan is : \n1)10%Stock\n2)20%Sukuk\n 3)70%Real Estate')
    elif (Score >=18) &(Score<=24):
        degree3='Moderate' 
        print('you are :  ',degree3)
        print('your invetgate plan is : \n1)40%Stock\n2)30%Sukuk\n3)30%Real Estate')
    elif (Score >=25) &(Score<=31):
        degree4='Aggressive'
        print('you are : ',degree4)
        print('your invetgate plan is : \n1)70%Stock\n2)10%Sukuk\n3)20%Real Estate')
    else:
        degree5='Very Aggressive'
        print('you are : ',degree5)
        print('your invetgate plan is : \n1)70%Stock\n2)10%Sukuk \n3)20%Real Estate')

# %%
Type_investment=['by yourself','Investment company']
Investment_company={'1-ABYAN Capital':'https://abyancapital.sa/','2-tamra capital':'https://tamracapital.sa/','3-derayah capital':'https://web.derayah.com/ar/'}

full_name=lambda first_name =input('first name '),last_name=input('last name '):first_name +" "+last_name

print ('Welcome ',full_name())

                     #https://bobbyhadz.com/blog/python-input-validation
while True:
    try:
        Type=int(input('What method do you prefer \n1)by yourself \n2)Investment company\n'))
    except ValueError:
        print("Please enter a valid integer 1or 2")
        continue
    if Type == 1 or Type == 2:
            break
    else:
        print('The integer must be in the range 1-5')
        
if int(Type) == 1 :
    RiskQues()
    
else:
    for i in Investment_company:
        print("{}\t{}".format(i,Investment_company[i]))
# Out:
# first name kjh
# last name kgb
# Welcome  kjh kgb
# What method do you prefer
# 1)by yourself
# 2)Investment company
# 2
# 1-ABYAN Capital	https://abyancapital.sa/
# 2-tamra capital	https://tamracapital.sa/
# 3-derayah capital	https://web.derayah.com/ar/
