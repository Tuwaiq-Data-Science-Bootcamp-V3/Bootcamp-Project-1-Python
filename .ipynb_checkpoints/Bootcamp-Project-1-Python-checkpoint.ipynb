# %%
import random

# Dictionary to store student data
students = {}

# Function to add a student
def add_student(name, age, grade): 
    students[name] = {'Age': age, 'Grade': grade}

# Function to get student details
def get_student_details(name):
    if name in students:
        return students[name]
    else:
        return 'Student not found!'

# Lambda function
def filter_students_by_grade(min_grade):
    filtered_students = {name: details for name, details in students.items() if details['Grade'] >= min_grade and name != 'Student not found!'}
    return filtered_students


while True:
    print("Student Management System")
    print("1. Add Student")
    print("2. Get Student Details")
    print("3. Filter Students by Grade")
    print("4. Exit")
    choice = input("Enter your choice (1-4): ")

    if choice == '1':
        name = input("Enter student name: ")
        age = int(input("Enter student age: "))
        grade = float(input("Enter student grade: "))
        add_student(name, age, grade)
        print("Student added successfully!")
    elif choice == '2':
        name = input("Enter student name: ")
        details = get_student_details(name)
        print("Student Details:")
        print("Name:", name)
        if isinstance(details, dict):
            print("Age:", details['Age'])
            print("Grade:", details['Grade'])
        else:
            print(details)
    elif choice == '3':
        min_grade = float(input("Enter the minimum grade: "))
        filtered_students = filter_students_by_grade(min_grade)
        print("Filtered Students:")
        if len(filtered_students) > 0:
            for name, details in filtered_students.items():
                print("Name:", name)
                print("Age:", details['Age'])
                print("Grade:", details['Grade'])
                print("-----------")
        else:
            print("No students meet the minimum grade.")
    elif choice == '4':
        print("Exit")
        break
    else:
        print("Invalid choice! Please try again.")
# Out:
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 5
# Invalid choice! Please try again.
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 1
# Enter student name: Faris
# Enter student age: 24
# Enter student grade: 100
# Student added successfully!
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): Feras
# Invalid choice! Please try again.
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 1
# Enter student name: Feras
# Enter student age: 25
# Enter student grade: 80.6
# Student added successfully!
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 2
# Enter student name: Faris
# Student Details:
# Name: Faris
# Age: 24
# Grade: 100.0
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 3
# Enter the minimum grade: 99
# Filtered Students:
# Name: Faris
# Age: 24
# Grade: 100.0
# -----------
# Student Management System
# 1. Add Student
# 2. Get Student Details
# 3. Filter Students by Grade
# 4. Exit
# Enter your choice (1-4): 4
# Exit
