# %%
#-----------------------------System to store and distribute a volunteer team in Event-----------------------------
import random
#This is a dictionary to store volunteer teams details later
volunteers ={}
#These are virtual locations for Invent.We will randomly distribute each team into an area using the Random algorithm.
LocationOfTheTeam=["Loc-A","Loc-B","Loc-C","Loc-D"]

#This input will take the user of the system.To know who entered the details.
Input0 = input("Please enter your name\n)

#lambda function we will use it to print user of the system each time we want.
User = lambda input0 : f"The user of the system = {input0}"
#AddVolunter function to print the details of the teams               
def AddVolunter(Input2,Input3,Input4,location,Input0):
   print(volunteers)


    

Input1 = int(input("Choose 1 to add a new volunteer team \nCoose 2 or more to stop the system\n"))

  
if Input1 == 1:
        while True:
            print(User(Input0))
            Input2 = input("Please enter team name or press q to quit\n")
               #In the input of team name we can press q to stop the system
            if Input2 == 'q':
                break
               #each loop the random algorithm will put each team in random place
            location = random.choice(LocationOfTheTeam)
            Input3 = input("Please enter the kind of the team.\nIt is a health volunteer? or organize volunteer? or genral volunteer? or else\n")
            Input4 = int(input("Please enter the number of team members\n"))
               #Here to store details of the team on dictionary
            volunteers[Input2] = {"Kind of the team": Input3, "Number of the team": Input4,"The location of the team ":location,"The user" :Input0}
            
            
            
           
elif Input1 == 2:
    print(User(Input0))
    print("The system stop")
           
            
else:
    print(f"The input not correct , Please choose between 1 or 2 Mr {Input0}")
            
            

AddVolunter(Input2, Input3, Input4,location,Input0)
