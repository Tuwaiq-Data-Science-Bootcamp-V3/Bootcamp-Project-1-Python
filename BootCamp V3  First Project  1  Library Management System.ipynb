# %%
#------ 1

# Creating a library as a list of dictionary

Main_library=[]



# Creating a function to add books to the system


def add_book(id, title):
    
    book= {'id': id, 'title': title, 'is_available': True }
    Main_library.append(book)
    
    
# creating a while method to break after the user enter the id and the title
    
y= False 

while (True):
    if not x:
        x= input('Please enter the id of the book (or type "q" to quit): ')
        if x=="q":
            break
        y = input('Please enter the title of the book:  ')
        add_book(x,y)
        y= True
    else:
        break

print(library)

# %%
#-------2


# Creating a users list as a list of dictionary

users=[]


def register_user(id, name):
    user = {'id': id, 'name': name, 'borrowed_books': []}
    users.append(user)
    
# creating a while method to break after the user enter the id and the name
    
user_registered= False

while (True):
    if not user_registered:
        x = input('Please enter your id (or type "q" to quit): ')
        if x == 'q':
            break
        y = input('Please enter your name: ')
        register_user(x, y)
        user_registered=True
    else:
        break

# %%
#-------3





def borrow_book(user_id,book_id):
    
# to find the user and the book in the library

    user= (user for user in users if user['id']==user_id)
    book= (book for book in Main_library if book['id']==book_id)
    
    
# to find the book and user if they exist and if the book is available or not    
    
    if book and user and book['is_available']:
        book['is_available']= False
        user['borrowed_books'].append(book_id)
        print('This book now is borrowed')
y= False

while (True):
    if not y:
    x = input('Please enter your name (or type "q" to quit): ')
    if x == 'q':
        break
    y = input('Please enter book''s name (or type "q" to quit): ')
    borrow_book(x,y)
    y=True

# %%
#--------------- 4

# This is jsut a way to view the books that are in the system.

def view_books():
    
    for books in Main_library:
        print(f'ID:{book['id']},Title:{book['title']}, Avalibale:{book['is_available']} )

# %%
#--------------- 5 


# This is a lambda function which sort all the books in the system 


sorting_books= lambda : sorted(Main_library, key=lambda book: book['title'],reverse= False)

# Sorted books
sorted_books = sorting_books()
print("\nSorted books:")
for book in sorted_books:
    print(f"ID: {book['id']}, Title: {book['title']}, Available: {book['is_available']}")

# %%
# Here I joined all the functions by calling all of them to let the system work







#---------------------------------------------------------------










# Creating a library as a list of dictionary

Main_library=[]

users=[]


# Creating a function to add books to the system


def add_book(id, title):
    
    book= {'id': id, 'title': title, 'is_available': True }
    Main_library.append(book)
    
    
# creating a while method to break after the user enter the id and the title
    
z= False 

while (True):
    if not z:
        x= input('Please enter the id of the book (or type "q" to quit): ')
        if x=="q":
            break
        y = input('Please enter the title of the book:  ')

        z= True
    else:
        break




# Creating a users list as a list of dictionary


def register_user(id, name):
    user = {'id': id, 'name': name, 'borrowed_books': []}
    users.append(user)
    
# creating a while method to break after the user enter the id and the name
    
user_registered= False

while (True):
    if not user_registered:
        x = input('Please enter your id (or type "q" to quit): ')
        if x == 'q':
            break
        y = input('Please enter your name: ')
        user_registered=True
    else:
        break






def borrow_book(user_id,book_id):
    
# to find the user and the book in the library

    user= list(user for user in users if user['id']==user_id)
    book= list(book for book in Main_library if book['id']==book_id)
    


# to find the book and user if they exist and if the book is available or not    
    
    if book and user and book[0]['is_available']:
        book[0]['is_available']= False
        user[0]['borrowed_books'].append(book_id)
        print('This book now is borrowed')

        
z= False

while (True):
    if not z:
        x = input('Please enter your name for borrowing (or type "q" to quit): ')
        if x == 'q':
            break
        y = input('Please enter book''s name (or type "q" to quit): ')
        z=True
    else:
        break      
        
# This is jsut a way to view the books that are in the system.

def view_books():
    
    for book in library:
        print(f"ID:{book['id']}, Title:{book['title']}, Available:{book['is_available']}")
              

              
# This is a lambda function which sort all the books in the system 


sorting_books= lambda : sorted(library, key=lambda book: book['title'],reverse= False)







#add_book(x,y)
add_book(x,y)
add_book(x,y)
view_books()


register_user(x,y)
view_books()

borrow_book(x,y)
view_books()




# Sorted books
sorted_books = sorting_books()
print("\nSorted books:")
for book in sorted_books:
    print(f"ID: {book['id']}, Title: {book['title']}, Available: {book['is_available']}")
